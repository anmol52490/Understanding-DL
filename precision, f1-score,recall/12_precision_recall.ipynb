# %%
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix , classification_report
import pandas as pd

# %%
truth =      ["Dog","Not a dog","Dog","Dog",      "Dog", "Not a dog", "Not a dog", "Dog",       "Dog", "Not a dog"]
prediction = ["Dog","Dog",      "Dog","Not a dog","Dog", "Not a dog", "Dog",       "Not a dog", "Dog", "Dog"]

# %%
from sklearn.metrics import confusion_matrix
cn = confusion_matrix(truth,prediction)
cn
# Out:
# array([[4, 2],
#        [3, 1]], dtype=int64)

# %%
import seaborn as sn 
import matplotlib.pyplot as plt
plt.figure(figsize = (7,7))
labels = ['Dog','Not a Dog']
sn.heatmap(cn,annot=True, xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(58.222222222222214, 0.5, 'Truth')

# %%
print(classification_report(truth, prediction))
# Out:
#               precision    recall  f1-score   support
#
#          Dog       0.57      0.67      0.62         6
#    Not a dog       0.33      0.25      0.29         4
#
#     accuracy                           0.50        10
#    macro avg       0.45      0.46      0.45        10
# weighted avg       0.48      0.50      0.48        10

# %% [markdown]
# **f1 score for Dog class**

# %%
2*(0.57*0.67/(0.57+0.67))
# Out:
# 0.6159677419354839

# %% [markdown]
# **f1 score for Not a dog class**

# %%
2*(0.33*0.25/(0.33+0.25))
# Out:
# 0.2844827586206896
